# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("whitegrid")

# %%
latency_dataset = pd.read_csv("../data/results/latencies.csv")
latency_dataset
# Out:
#          time  latency[100.0, 1.0, AdvancedLoadBasedReconfiguration]  \
# 0      10.005                                           2.311636
# 1      20.012                                           3.148857
# 2      30.003                                           3.819034
# 3      40.004                                           3.967678
# 4      50.002                                           3.967678
# ..        ...                                                ...
# 355  3560.000                                           3.967678
# 356  3570.000                                           3.967678
# 357  3580.000                                           3.967678
# 358  3590.000                                           3.967678
# 359  3600.000                                           4.211072
#
#      latency[100.0, 10.0, SimpleLoadBasedReconfiguration]  \
# 0                                             2.009129
# 1                                             2.905723
# 2                                             3.389053
# 3                                             3.497258
# 4                                             3.497258
# ..                                                 ...
# 355                                           3.532029
# 356                                           3.532029
# 357                                           3.532029
# 358                                           3.532029
# 359                                           3.532029
#
#      latency[100.0, 10.0, AdvancedLoadBasedReconfiguration]  \
# 0                                             2.302645
# 1                                             2.468646
# 2                                             2.983105
# 3                                             3.134067
# 4                                             3.134067
# ..                                                 ...
# 355                                           3.115516
# 356                                           3.115516
# 357                                           3.115516
# 358                                           3.115516
# 359                                           3.115516
#
#      latency[100.0, 1.0, SimpleLoadBasedReconfiguration]
# 0                                             2.040993
# 1                                             2.945331
# 2                                             3.628515
# 3                                             3.783175
# 4                                             3.783175
# ..                                                 ...
# 355                                           3.783175
# 356                                           3.783175
# 357                                           3.783175
# 358                                           3.783175
# 359                                           3.783175
#
# [360 rows x 5 columns]

# %%
qos_dataset = pd.read_csv("../data/results/offloading_qos.csv")
qos_dataset
# Out:
#          time  offloadingQoS[100.0, 1.0, AdvancedLoadBasedReconfiguration]  \
# 0       0.000                                           1.000000
# 1      10.005                                           0.561224
# 2      20.012                                           0.826531
# 3      30.003                                           0.959184
# 4      40.004                                           0.989796
# ..        ...                                                ...
# 356  3560.000                                           0.989796
# 357  3570.000                                           0.989796
# 358  3580.000                                           0.989796
# 359  3590.000                                           0.989796
# 360  3600.000                                           0.979592
#
#      offloadingQoS[100.0, 10.0, SimpleLoadBasedReconfiguration]  \
# 0                                             1.000000
# 1                                             0.336735
# 2                                             0.357143
# 3                                             0.326531
# 4                                             0.336735
# ..                                                 ...
# 356                                           0.336735
# 357                                           0.336735
# 358                                           0.336735
# 359                                           0.336735
# 360                                           0.336735
#
#      offloadingQoS[100.0, 10.0, AdvancedLoadBasedReconfiguration]  \
# 0                                             1.000000
# 1                                             0.377551
# 2                                             0.387755
# 3                                             0.387755
# 4                                             0.397959
# ..                                                 ...
# 356                                           0.408163
# 357                                           0.408163
# 358                                           0.408163
# 359                                           0.408163
# 360                                           0.408163
#
#      offloadingQoS[100.0, 1.0, SimpleLoadBasedReconfiguration]
# 0                                             1.000000
# 1                                             0.561224
# 2                                             0.826531
# 3                                             0.959184
# 4                                             0.989796
# ..                                                 ...
# 356                                           0.989796
# 357                                           0.989796
# 358                                           0.989796
# 359                                           0.989796
# 360                                           0.989796
#
# [361 rows x 5 columns]

# %%
load_dataset = pd.read_csv("../data/results/effective_load_mean.csv")
load_dataset
# Out:
#          time  \
# 0      10.005
# 1      20.012
# 2      30.003
# 3      40.004
# 4      50.002
# ..        ...
# 355  3560.000
# 356  3570.000
# 357  3580.000
# 358  3590.000
# 359  3600.000
#
#      effectiveLoadMean[100.0, 1.0, AdvancedLoadBasedReconfiguration]  \
# 0                                            24.817180
# 1                                            29.817180
# 2                                            30.417180
# 3                                            30.417180
# 4                                            30.417180
# ..                                                 ...
# 355                                          30.603674
# 356                                          32.113555
# 357                                          32.113555
# 358                                          32.113555
# 359                                          27.118033
#
#      effectiveLoadMean[100.0, 10.0, SimpleLoadBasedReconfiguration]  \
# 0                                            87.417180
# 1                                            87.417180
# 2                                            87.417180
# 3                                            87.417180
# 4                                            87.417180
# ..                                                 ...
# 355                                          89.603674
# 356                                          89.113555
# 357                                          89.113555
# 358                                          89.113555
# 359                                          87.518033
#
#      effectiveLoadMean[100.0, 10.0, AdvancedLoadBasedReconfiguration]  \
# 0                                            85.417180
# 1                                            85.417180
# 2                                            85.417180
# 3                                            85.417180
# 4                                            85.417180
# ..                                                 ...
# 355                                          87.603674
# 356                                          89.113555
# 357                                          89.113555
# 358                                          89.113555
# 359                                          87.518033
#
#      effectiveLoadMean[100.0, 1.0, SimpleLoadBasedReconfiguration]
# 0                                            29.617180
# 1                                            34.817180
# 2                                            37.417180
# 3                                            37.417180
# 4                                            37.417180
# ..                                                 ...
# 355                                          37.603674
# 356                                          39.113555
# 357                                          39.113555
# 358                                          39.113555
# 359                                          39.518033
#
# [360 rows x 5 columns]

# %% [markdown]
# ## Plot Server load
#
# Average load of the system captured in 24h

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(x="time", y="value", hue="variable", data = pd.melt(load_dataset, ["time"]))
ax.set(xlabel='Time (s)', ylabel='Server load (%)')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# # Plot QoS of the offloading capacity
#
# Metric showing the QoS of the offloading process.
# The metric is computed as: $\frac{can\_offloading}{want\_offloading}$ and the metric range is in $[0 \ldots 1]$

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(x="time", y="value", hue="variable", data = pd.melt(qos_dataset, ["time"]))
ax.set(xlabel='Time (s)', ylabel='QoS')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(x="time", y="value", hue="variable", data = pd.melt(latency_dataset, ["time"]))
ax.set(xlabel='Time (s)', ylabel='Latency (ms)')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
